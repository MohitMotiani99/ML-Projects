# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
train=pd.read_csv('train.csv')

# %%
train
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0              FDA15        9.300          Low Fat         0.016047
# 1              DRC01        5.920          Regular         0.019278
# 2              FDN15       17.500          Low Fat         0.016760
# 3              FDX07       19.200          Regular         0.000000
# 4              NCD19        8.930          Low Fat         0.000000
# ...              ...          ...              ...              ...
# 8518           FDF22        6.865          Low Fat         0.056783
# 8519           FDS36        8.380          Regular         0.046982
# 8520           NCJ29       10.600          Low Fat         0.035186
# 8521           FDN46        7.210          Regular         0.145221
# 8522           DRG01       14.800          Low Fat         0.044878
#
#                   Item_Type  Item_MRP Outlet_Identifier  \
# 0                     Dairy  249.8092            OUT049
# ...

# %%
train.loc[45,:]
# Out:
# Item_Identifier                      FDM39
# Item_Weight                           6.42
# Item_Fat_Content                        LF
# Item_Visibility                  0.0894989
# Item_Type                            Dairy
# Item_MRP                             178.1
# Outlet_Identifier                   OUT010
# Outlet_Establishment_Year             1998
# Outlet_Size                            NaN
# Outlet_Location_Type                Tier 3
# Outlet_Type                  Grocery Store
# Item_Outlet_Sales                    358.2
# Name: 45, dtype: object

# %%
for i in range(train.shape[0]):
    if train.loc[i,'Item_Fat_Content'][0]=='l' or train.loc[i,'Item_Fat_Content'][0]=='L' :
        train.loc[i,'Item_Fat_Content']='Low Fat'
    elif train.loc[i,'Item_Fat_Content'][0]=='r'or train.loc[i,'Item_Fat_Content'][0]=='R' :
        train.loc[i,'Item_Fat_Content']='Regular'

# %%
train
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0              FDA15        9.300          Low Fat         0.016047
# 1              DRC01        5.920          Regular         0.019278
# 2              FDN15       17.500          Low Fat         0.016760
# 3              FDX07       19.200          Regular         0.000000
# 4              NCD19        8.930          Low Fat         0.000000
# ...              ...          ...              ...              ...
# 8518           FDF22        6.865          Low Fat         0.056783
# 8519           FDS36        8.380          Regular         0.046982
# 8520           NCJ29       10.600          Low Fat         0.035186
# 8521           FDN46        7.210          Regular         0.145221
# 8522           DRG01       14.800          Low Fat         0.044878
#
#                   Item_Type  Item_MRP Outlet_Identifier  \
# 0                     Dairy  249.8092            OUT049
# ...

# %%
train.loc[45,:]
# Out:
# Item_Identifier                      FDM39
# Item_Weight                           6.42
# Item_Fat_Content                   Low Fat
# Item_Visibility                  0.0894989
# Item_Type                            Dairy
# Item_MRP                             178.1
# Outlet_Identifier                   OUT010
# Outlet_Establishment_Year             1998
# Outlet_Size                            NaN
# Outlet_Location_Type                Tier 3
# Outlet_Type                  Grocery Store
# Item_Outlet_Sales                    358.2
# Name: 45, dtype: object

# %%
from sklearn.preprocessing import LabelEncoder

order_fat_content={}
order_fat_content['None']=0

label_encoder=LabelEncoder()

train['Item_Fat_Content']=train['Item_Fat_Content'].fillna('None')
unique_fat_content_values=train['Item_Fat_Content'].unique()
print(train['Item_Fat_Content'].unique())
for i in range(len(unique_fat_content_values)):
    order_fat_content[unique_fat_content_values[i]]=i+1
    

print(order_fat_content)
# Out:
# ['Low Fat' 'Regular']
# {'None': 0, 'Low Fat': 1, 'Regular': 2}

# %%
train['Item_Fat_Content']=train['Item_Fat_Content'].map(order_fat_content)

train
# Out:
#      Item_Identifier  Item_Weight  Item_Fat_Content  Item_Visibility  \
# 0              FDA15        9.300                 1         0.016047
# 1              DRC01        5.920                 2         0.019278
# 2              FDN15       17.500                 1         0.016760
# 3              FDX07       19.200                 2         0.000000
# 4              NCD19        8.930                 1         0.000000
# ...              ...          ...               ...              ...
# 8518           FDF22        6.865                 1         0.056783
# 8519           FDS36        8.380                 2         0.046982
# 8520           NCJ29       10.600                 1         0.035186
# 8521           FDN46        7.210                 2         0.145221
# 8522           DRG01       14.800                 1         0.044878
#
#                   Item_Type  Item_MRP Outlet_Identifier  \
# 0                     Dairy  249.8092            OUT049
# ...

# %%
train['Item_Type']=train['Item_Type'].fillna('None')

order_item_type={}
order_item_type['None']=0

unique_item_type_values=train['Item_Type'].unique()
for i in range(len(unique_item_type_values)):
    order_item_type[unique_item_type_values[i]]=i+1;

print(unique_item_type_values)
print(order_item_type)
# Out:
# ['Dairy' 'Soft Drinks' 'Meat' 'Fruits and Vegetables' 'Household'
#  'Baking Goods' 'Snack Foods' 'Frozen Foods' 'Breakfast'
#  'Health and Hygiene' 'Hard Drinks' 'Canned' 'Breads' 'Starchy Foods'
#  'Others' 'Seafood']
# {'None': 0, 'Dairy': 1, 'Soft Drinks': 2, 'Meat': 3, 'Fruits and Vegetables': 4, 'Household': 5, 'Baking Goods': 6, 'Snack Foods': 7, 'Frozen Foods': 8, 'Breakfast': 9, 'Health and Hygiene': 10, 'Hard Drinks': 11, 'Canned': 12, 'Breads': 13, 'Starchy Foods': 14, 'Others': 15, 'Seafood': 16}

# %%
train['Item_Type']=train['Item_Type'].map(order_item_type)

train
# Out:
#      Item_Identifier  Item_Weight  Item_Fat_Content  Item_Visibility  \
# 0              FDA15        9.300                 1         0.016047
# 1              DRC01        5.920                 2         0.019278
# 2              FDN15       17.500                 1         0.016760
# 3              FDX07       19.200                 2         0.000000
# 4              NCD19        8.930                 1         0.000000
# ...              ...          ...               ...              ...
# 8518           FDF22        6.865                 1         0.056783
# 8519           FDS36        8.380                 2         0.046982
# 8520           NCJ29       10.600                 1         0.035186
# 8521           FDN46        7.210                 2         0.145221
# 8522           DRG01       14.800                 1         0.044878
#
#       Item_Type  Item_MRP Outlet_Identifier  Outlet_Establishment_Year  \
# ...

# %%
train['Item_Weight']=train['Item_Weight'].fillna(0.0)
train['Item_Visibility']=train['Item_Visibility'].fillna(0.0)
train['Item_MRP']=train['Item_MRP'].fillna(0.0)

# %%
train
# Out:
#      Item_Identifier  Item_Weight  Item_Fat_Content  Item_Visibility  \
# 0              FDA15        9.300                 1         0.016047
# 1              DRC01        5.920                 2         0.019278
# 2              FDN15       17.500                 1         0.016760
# 3              FDX07       19.200                 2         0.000000
# 4              NCD19        8.930                 1         0.000000
# ...              ...          ...               ...              ...
# 8518           FDF22        6.865                 1         0.056783
# 8519           FDS36        8.380                 2         0.046982
# 8520           NCJ29       10.600                 1         0.035186
# 8521           FDN46        7.210                 2         0.145221
# 8522           DRG01       14.800                 1         0.044878
#
#       Item_Type  Item_MRP Outlet_Identifier  Outlet_Establishment_Year  \
# ...

# %%
train.loc[7,:]
# Out:
# Item_Identifier                          FDP10
# Item_Weight                                  0
# Item_Fat_Content                             1
# Item_Visibility                        0.12747
# Item_Type                                    7
# Item_MRP                               107.762
# Outlet_Identifier                       OUT027
# Outlet_Establishment_Year                 1985
# Outlet_Size                             Medium
# Outlet_Location_Type                    Tier 3
# Outlet_Type                  Supermarket Type3
# Item_Outlet_Sales                      4022.76
# Name: 7, dtype: object

# %%
trainx=train[['Item_Weight','Item_Fat_Content','Item_Visibility','Item_Type','Item_MRP']].values

# %%
from sklearn.preprocessing import StandardScaler

scalar=StandardScaler()

trainx=scalar.fit_transform(trainx)

# %%
trainx
# Out:
# array([[-0.20999534, -0.73814723, -0.97073217, -1.5402496 ,  1.74745381],
#        [-0.73553195,  1.35474328, -0.90811123, -1.26769027, -1.48902325],
#        [ 1.06497512, -0.73814723, -0.95691733, -0.99513095,  0.01004021],
#        ...,
#        [-0.00786588, -0.73814723, -0.59978449,  0.91278433, -0.89720755],
#        [-0.53495733,  1.35474328,  1.53287976,  0.09510635, -0.60797692],
#        [ 0.64516777, -0.73814723, -0.41193591, -1.26769027, -1.05226104]])

# %%
trainy=train['Item_Outlet_Sales'].values

# %%
trainy=trainy.reshape(trainy.shape[0],1)

trainy=scalar.fit_transform(trainy)

# %%
trainy
# Out:
# array([[ 0.910601  ],
#        [-1.01844035],
#        [-0.04923754],
#        ...,
#        [-0.57909963],
#        [-0.19672492],
#        [-0.82959407]])

# %%
from sklearn.model_selection import train_test_split

trainx,validx,trainy,validy=train_test_split(trainx,trainy,test_size=0.2)

# %%
trainx[:][1]
# Out:
# array([-0.82882247, -0.73814723,  0.52213891,  0.91278433, -0.5961866 ])

# %%
from sklearn.neighbors import KNeighborsRegressor
from sklearn.metrics import r2_score

acc_scores=np.zeros((60));

for k in range(1,61):
    model=KNeighborsRegressor(n_neighbors=k)
    model.fit(trainx,trainy)
    
    predy=model.predict(validx)
    acc_scores[k-1]=r2_score(validy,predy)

# %%
plt.plot(range(1,61),acc_scores,'bo')
plt.show()

# %%
acc_scores
# Out:
# array([-0.15242473,  0.08898054,  0.17953946,  0.21380544,  0.22768376,
#         0.25048449,  0.26395254,  0.2738513 ,  0.28136485,  0.28957367,
#         0.29175769,  0.29751998,  0.3019393 ,  0.30877714,  0.31025994,
#         0.31190967,  0.31678063,  0.31635873,  0.3174142 ,  0.31900611,
#         0.3208876 ,  0.32194765,  0.31953329,  0.32085398,  0.31922743,
#         0.32182108,  0.32128687,  0.32419435,  0.32658162,  0.32617952,
#         0.3255321 ,  0.32561204,  0.32581466,  0.32632415,  0.32705723,
#         0.32683748,  0.32736542,  0.32956467,  0.33019376,  0.32908769,
#         0.32921766,  0.32964591,  0.33163186,  0.33149031,  0.33261391,
#         0.33322633,  0.33370941,  0.33266446,  0.33345877,  0.33498391,
#         0.33279023,  0.33374809,  0.33481741,  0.3360625 ,  0.33540662,
#         0.33539202,  0.33615726,  0.33497911,  0.33505978,  0.3357571 ])

# %%
model=KNeighborsRegressor(n_neighbors=60)
model.fit(trainx,trainy)
# Out:
# KNeighborsRegressor(n_neighbors=60)

# %%
test=pd.read_csv('test.csv')

# %%
for i in range(test.shape[0]):
    if test.loc[i,'Item_Fat_Content'][0]=='l' or test.loc[i,'Item_Fat_Content'][0]=='L' :
        test.loc[i,'Item_Fat_Content']='Low Fat'
    elif test.loc[i,'Item_Fat_Content'][0]=='r'or test.loc[i,'Item_Fat_Content'][0]=='R' :
        test.loc[i,'Item_Fat_Content']='Regular'

# %%
test['Item_Fat_Content']=test['Item_Fat_Content'].fillna('None')
test['Item_Fat_Content']=test['Item_Fat_Content'].map(order_fat_content)

test['Item_Type']=test['Item_Type'].fillna('None')
test['Item_Type']=test['Item_Type'].map(order_item_type)

test['Item_Weight']=test['Item_Weight'].fillna(0.0)
test['Item_Visibility']=test['Item_Visibility'].fillna(0.0)
test['Item_MRP']=test['Item_MRP'].fillna(0.0)

# %%
test
# Out:
#      Item_Identifier  Item_Weight  Item_Fat_Content  Item_Visibility  \
# 0              FDW58       20.750                 1         0.007565
# 1              FDW14        8.300                 2         0.038428
# 2              NCN55       14.600                 1         0.099575
# 3              FDQ58        7.315                 1         0.015388
# 4              FDY38        0.000                 2         0.118599
# ...              ...          ...               ...              ...
# 5676           FDB58       10.500                 2         0.013496
# 5677           FDD47        7.600                 2         0.142991
# 5678           NCO17       10.000                 1         0.073529
# 5679           FDJ26       15.300                 2         0.000000
# 5680           FDU37        9.500                 2         0.104720
#
#       Item_Type  Item_MRP Outlet_Identifier  Outlet_Establishment_Year  \
# ...

# %%
testx=test[['Item_Weight','Item_Fat_Content','Item_Visibility','Item_Type','Item_MRP']]

# %%
testx=scalar.fit_transform(testx)

# %%
testx
# Out:
# array([[ 1.59945346, -0.74081066, -1.13407715,  0.09525004, -0.53655526],
#        [-0.3460522 ,  1.34987258, -0.53185019, -1.54698202, -0.86893692],
#        [ 0.63842055, -0.74081066,  0.6613164 ,  2.28489279,  1.62984753],
#        ...,
#        [-0.08040082, -0.74081066,  0.15307374,  0.91636607, -0.36048475],
#        [ 0.74780641,  1.34987258, -1.28168987,  1.46377676,  1.19084433],
#        [-0.15853358,  1.34987258,  0.76171558,  1.46377676, -0.99067406]])

# %%
predy=model.predict(testx)

# %%
predy
# Out:
# array([[-0.20425537],
#        [-0.45246077],
#        [ 0.58263665],
#        ...,
#        [-0.24037287],
#        [ 0.51636488],
#        [-0.52201655]])

# %%
predy.shape
# Out:
# (5681, 1)

# %%
scalar
# Out:
# StandardScaler()

# %%
scalar2=StandardScaler()

scalar2=scalar2.fit(predy)

# %%
scalar2.mean_
# Out:
# array([0.01146198])

# %%
scalar2.var_
# Out:
# array([0.29710674])

# %%
predy
# Out:
# array([[-0.20425537],
#        [-0.45246077],
#        [ 0.58263665],
#        ...,
#        [-0.24037287],
#        [ 0.51636488],
#        [-0.52201655]])

# %%
predy=scalar2.inverse_transform(predy)
predy
# Out:
# array([[-0.09987251],
#        [-0.23516306],
#        [ 0.32904265],
#        ...,
#        [-0.11955925],
#        [ 0.29291956],
#        [-0.27307618]])

# %%
predy.shape
# Out:
# (5681, 1)
