# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
data=pd.read_csv('insurance.csv')

# %%
data.head()
# Out:
#    age  sex     bmi  children  smoker  region      charges
# 0   19    0  27.900         0       1       3  16884.92400
# 1   18    1  33.770         1       0       2   1725.55230
# 2   28    1  33.000         3       0       2   4449.46200
# 3   33    1  22.705         0       0       1  21984.47061
# 4   32    1  28.880         0       0       1   3866.85520

# %%
train_x=data['bmi']

# %%
train_x.head()
# Out:
# 0    27.900
# 1    33.770
# 2    33.000
# 3    22.705
# 4    28.880
# Name: bmi, dtype: float64

# %%
train_y=data['charges']

# %%
train_y.head()
# Out:
# 0    16884.92400
# 1     1725.55230
# 2     4449.46200
# 3    21984.47061
# 4     3866.85520
# Name: charges, dtype: float64

# %%
from sklearn.model_selection import train_test_split
train_x,test_x,train_y,test_y=train_test_split(train_x,train_y,test_size=0.2)

# %%
train_x.shape()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-11-a2cdfcd02154> in <module>
# ----> 1 train_x.shape()
#
# TypeError: 'tuple' object is not callable

# %%
len(train_x)
# Out:
# 278

# %%
len(train_y)
# Out:
# 278

# %%
len(test_x)
# Out:
# 70

# %%
len(test_y)
# Out:
# 70

# %%
train_x=np.asarray(train_x)

# %%
train_x.shape()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-29-a2cdfcd02154> in <module>
# ----> 1 train_x.shape()
#
# TypeError: 'tuple' object is not callable

# %%
train_x
# Out:
# array([36.   , 28.975, 22.22 , 32.11 , 24.3  , 19.8  , 26.6  , 26.315,
#        35.72 , 27.55 , 33.25 , 35.86 , 26.29 , 28.9  , 24.51 , 26.41 ,
#        39.1  , 28.785, 27.74 , 28.88 , 34.105, 31.16 , 31.825, 35.53 ,
#        27.645, 42.35 , 32.11 , 26.98 , 28.785, 26.8  , 25.2  , 41.23 ,
#        27.5  , 32.2  , 27.55 , 33.66 , 24.795, 36.955, 26.885, 34.8  ,
#        26.73 , 36.48 , 33.155, 27.4  , 31.92 , 34.2  , 20.8  , 27.5  ,
#        35.9  , 30.8  , 37.1  , 32.49 , 26.4  , 36.4  , 32.775, 27.74 ,
#        38.   , 37.05 , 33.8  , 38.06 , 30.2  , 41.895, 27.94 , 17.385,
#        31.57 , 27.74 , 34.7  , 34.1  , 33.63 , 25.74 , 29.2  , 26.73 ,
#        30.3  , 32.4  , 31.825, 29.7  , 27.36 , 38.28 , 34.5  , 28.4  ,
#        22.99 , 25.3  , 37.7  , 35.3  , 36.67 , 17.29 , 23.1  , 26.6  ,
#        28.05 , 24.7  , 38.83 , 39.9  , 36.08 , 25.175, 48.07 , 33.345,
#        23.085, 25.41 , 33.   , 26.6  , 20.9  , 22.88 , 27.5  , 24.53 ,
# ...

# %%
train_x.shape
# Out:
# (278,)

# %%
train_y.shape
# Out:
# (278,)

# %%
train_y
# Out:
# 139     2166.73200
# 122     2257.47525
# 235    19444.26580
# 200     2130.67590
# 277     2150.46900
#           ...
# 16     10797.33620
# 137     2045.68525
# 212     3537.70300
# 45     20630.28351
# 27     12268.63225
# Name: charges, Length: 278, dtype: float64

# %%
train_y=np.asarray(train_y)

# %%
train_y
# Out:
# array([ 2166.732  ,  2257.47525, 19444.2658 ,  2130.6759 ,  2150.469  ,
#        17179.522  ,  3046.062  ,  2198.18985,  2404.7338 ,  2523.1695 ,
#         9722.7695 ,  1986.9334 , 27808.7251 ,  1743.214  ,  6710.1919 ,
#         7419.4779 , 14235.072  ,  2457.21115,  7281.5056 ,  3866.8552 ,
#         6600.20595, 43578.9394 , 13607.36875, 36950.2567 ,  4237.12655,
#        46151.1245 ,  4922.9159 , 11082.5772 ,  3385.39915, 35160.13457,
#        11837.16   ,  6610.1097 , 20177.67113, 47305.305  , 13217.0945 ,
#         4504.6624 , 10942.13205, 36219.40545,  4441.21315, 39836.519  ,
#         5002.7827 , 42760.5022 ,  6128.79745,  7726.854  , 37701.8768 ,
#        42856.838  ,  2302.3    ,  5003.853  , 11163.568  , 12105.32   ,
#         7740.337  ,  3490.5491 , 25992.82104, 51194.55914, 10435.06525,
#        29523.1656 , 12646.207  ,  7265.7025 , 47928.03   ,  7152.6714 ,
#         7441.053  , 43753.33705, 19107.7796 ,  2775.19215, 12557.6053 ,
# ...

# %%
test_x=np.asarray(test_x)
test_y=np.asarray(test_y)

# %%
from sklearn.linear_model import LinearRegression

model=LinearRegression().fit(train_x,train_y)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-37-8db857950292> in <module>
#       1 from sklearn.linear_model import LinearRegression
#       2
# ----> 3 model=LinearRegression().fit(train_x,train_y)
#
# c:\users\support\appdata\local\programs\python\python37\lib\site-packages\sklearn\linear_model\_base.py in fit(self, X, y, sample_weight)
#     504         n_jobs_ = self.n_jobs
#     505         X, y = self._validate_data(X, y, accept_sparse=['csr', 'csc', 'coo'],
# --> 506                                    y_numeric=True, multi_output=True)
#     507
#     508         if sample_weight is not None:
#
# c:\users\support\appdata\local\programs\python\python37\lib\site-packages\sklearn\base.py in _validate_data(self, X, y, reset, validate_separately, **check_params)
#     430                 y = check_array(y, **check_y_params)
#     431             else:
# ...

# %%
m=train_x.shape[0]
train_x=train_x.reshape(m,1)

# %%
train_y=train_y.reshape(m,1)

# %%
from sklearn.linear_model import LinearRegression

model=LinearRegression().fit(train_x,train_y)

# %%
model
# Out:
# LinearRegression()

# %%
test_x=test_x.reshape(test_x.shape[0],1)

# %%
test_y=test_y.reshape(test_y.shape[0],1)

# %%
pred_y=model.predict(test_x)

# %%
pred_y
# Out:
# array([[12501.44241231],
#        [18357.6117881 ],
#        [13537.57795192],
#        [13383.01629684],
#        [18357.6117881 ],
#        [19554.03348853],
#        [20172.28010885],
#        [10297.50770099],
#        [11144.73455106],
#        [ 7392.32103607],
#        [12438.47284913],
#        [17181.22585778],
#        [12501.44241231],
#        [15461.0118818 ],
#        [17098.22052449],
#        [17018.07744408],
#        [ 9241.33639128],
#        [ 6739.72738129],
#        [10165.84406889],
#        [15114.6792843 ],
#        [13102.5155154 ],
#        [ 9404.48480498],
#        [11808.77721733],
#        [10546.52370084],
#        [16491.42291566],
#        [10738.29464326],
#        [10492.14089628],
#        [10383.37528715],
#        [17979.79440902],
#        [16256.71818017],
#        [16279.61620314],
#        [12341.15625149],
#        [15658.50732995],
#        [13591.96075648],
#        [15114.6792843 ],
#        [12939.3671017 ],
#        [17350.09877721],
# ...

# %%
test_y.shape
# Out:
# (70, 1)

# %%
test_y
# Out:
# array([[14001.2867 ],
#        [20462.99766],
#        [ 5028.1466 ],
#        [ 1719.4363 ],
#        [12648.7034 ],
#        [ 5400.9805 ],
#        [11033.6617 ],
#        [17663.1442 ],
#        [ 3645.0894 ],
#        [ 4827.90495],
#        [ 8232.6388 ],
#        [13228.84695],
#        [19749.38338],
#        [ 4349.462  ],
#        [ 8124.4084 ],
#        [19144.57652],
#        [ 5354.07465],
#        [32734.1863 ],
#        [ 1705.6245 ],
#        [11879.10405],
#        [ 4337.7352 ],
#        [14711.7438 ],
#        [ 7742.1098 ],
#        [11520.09985],
#        [ 5246.047  ],
#        [16577.7795 ],
#        [24869.8368 ],
#        [ 5125.2157 ],
#        [ 9634.538  ],
#        [38746.3551 ],
#        [ 1137.4697 ],
#        [ 6746.7425 ],
#        [ 8334.45755],
#        [18157.876  ],
#        [14590.63205],
#        [30259.99556],
#        [38711.     ],
#        [ 7749.1564 ],
#        [17352.6803 ],
#        [ 7077.1894 ],
#        [ 8520.026  ],
# ...

# %%
pred_y
# Out:
# array([[12501.44241231],
#        [18357.6117881 ],
#        [13537.57795192],
#        [13383.01629684],
#        [18357.6117881 ],
#        [19554.03348853],
#        [20172.28010885],
#        [10297.50770099],
#        [11144.73455106],
#        [ 7392.32103607],
#        [12438.47284913],
#        [17181.22585778],
#        [12501.44241231],
#        [15461.0118818 ],
#        [17098.22052449],
#        [17018.07744408],
#        [ 9241.33639128],
#        [ 6739.72738129],
#        [10165.84406889],
#        [15114.6792843 ],
#        [13102.5155154 ],
#        [ 9404.48480498],
#        [11808.77721733],
#        [10546.52370084],
#        [16491.42291566],
#        [10738.29464326],
#        [10492.14089628],
#        [10383.37528715],
#        [17979.79440902],
#        [16256.71818017],
#        [16279.61620314],
#        [12341.15625149],
#        [15658.50732995],
#        [13591.96075648],
#        [15114.6792843 ],
#        [12939.3671017 ],
#        [17350.09877721],
# ...

# %%
from sklearn.metrics import r2_score
print("R^2 score: %f" %r2_score(test_y,pred_y))
# Out:
# R^2 score: -0.065686

# %%
print("mean error : %f" %(np.mean(np.absolute(pred_y-test_y))))
# Out:
# mean Accuracy : 9018.723106

# %%
test_y=test_y.reshape(-1)

# %%
test_y
# Out:
# array([14001.2867 , 20462.99766,  5028.1466 ,  1719.4363 , 12648.7034 ,
#         5400.9805 , 11033.6617 , 17663.1442 ,  3645.0894 ,  4827.90495,
#         8232.6388 , 13228.84695, 19749.38338,  4349.462  ,  8124.4084 ,
#        19144.57652,  5354.07465, 32734.1863 ,  1705.6245 , 11879.10405,
#         4337.7352 , 14711.7438 ,  7742.1098 , 11520.09985,  5246.047  ,
#        16577.7795 , 24869.8368 ,  5125.2157 ,  9634.538  , 38746.3551 ,
#         1137.4697 ,  6746.7425 ,  8334.45755, 18157.876  , 14590.63205,
#        30259.99556, 38711.     ,  7749.1564 , 17352.6803 ,  7077.1894 ,
#         8520.026  , 12265.5069 ,  6313.759  , 37742.5757 , 24393.6224 ,
#        21344.8467 ,  6948.7008 , 22412.6485 , 13981.85035,  5325.651  ,
#        11356.6609 ,  4463.2051 , 11741.726  , 10959.6947 ,  1837.237  ,
#        36837.467  ,  6079.6715 , 13405.3903 ,  4005.4225 , 21348.706  ,
#         8162.71625,  3392.9768 , 10407.08585,  4687.797  , 34838.873  ,
# ...

# %%
pred_y=pred_y.reshape(-1)

# %%
# Out:
# R^2 score: -0.0657

# %%
model.coef_
# Out:
# array([[572.45057437]])

# %%
model.intercept_
# Out:
# array([-3429.85707236])

# %%
plt.scatter(train_x,train_y,color='blue')
plt.plot(train_x,model.coef_[0][0]*train_x+model.intercept_[0],color='black')
plt.xlabel('BMI')
plt.ylabel('Insurance Charges')
plt.show()

# %%
plt.scatter(data['age'],data['charges'],color='blue')
plt.xlabel('Age')
plt.ylabel('Insurance Charges')
plt.show()

# %%
plt.scatter(data['smoker'],data['charges'],color='blue')
plt.xlabel('Smoker')
plt.ylabel('Insurance Charges')
plt.show()

# %%
plt.scatter(data['region'],data['charges'],color='blue')
plt.xlabel('Region')
plt.ylabel('Insurance Charges')
plt.show()

# %%
print("R^2 score: %.4f" %r2_score(test_y,pred_y))
# Out:
# R^2 score: -0.0657
